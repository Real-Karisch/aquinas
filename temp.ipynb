# %%
import os
from patristicCommentary import gospelChapterCounts
from bs4 import BeautifulSoup

# %%
with open('aquinas_commentary_matthew_1_to_12.html') as file:
    soup = BeautifulSoup(file)

# %%
soup.body
# Out:
# <body class="no-scroll-bar" spellcheck="false">
# <!-- Title Bar -->
# <div id="titleBar">
# <div class="btn-group">
# <button class="btn btn-primary dropdown-toggle" data-menu="mainmenu" id="menuButton" onclick="toggleDropdown(this);" type="button">
# <span class="fa fa-bars"></span>
# </button>
# <ul class="dropdown-menu toggle-menu" id="mainmenu" role="menu">
# <li class="dropdown-submenu" id="lang1MenuGroup">
# <a href="javascript:void(0)">Left Column</a>
# <ul class="dropdown-menu" id="lang1menu"></ul>
# </li>
# <li class="dropdown-submenu" id="lang2MenuGroup">
# <a href="javascript:void(0)">Right Column</a>
# <ul class="dropdown-menu" id="lang2menu"></ul>
# </li>
# <li class="divider"></li>
# <li class="dropdown-header">Options</li>
# <li><a href="javascript:void(0)" id="launchAlpheios" onclick="launchAlpheios();">Launch Alpheios</a></li>
# <li><a href="javascript:void(0)" id="openGotoDialog" onclick="openGotoDialog();">Go to Row<span class="dmenu-rt">(CTRL+G)</span></a></li>
# ...

# %%
soup
# Out:
# <head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title></title>
# </head>
